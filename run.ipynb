# %%
from hypersurface import *
import sympy as sp
from pprint import pprint

# %%
d = 4
z0, z1, z2, z3 = sp.symbols('z0, z1, z2, z3')
Z = [z0,z1,z2,z3]
f = z0**4 + z1**4 + z2**4 + z3**4
HS = Hypersurface(Z, f, d, 20)

# %%
HS.list_patches()
# Out:
# Number of Patches: 4
# Points in patch 1 : 26
# Points in patch 2 : 12
# Points in patch 3 : 14
# Points in patch 4 : 28

# %%
HS.patches[0].list_patches()
HS.patches[1].list_patches()
HS.patches[2].list_patches()
HS.patches[3].list_patches()
# Out:
# Number of Patches: 3
# Points in patch 1 : 4
# Points in patch 2 : 9
# Points in patch 3 : 6
# Number of Patches: 3
# Points in patch 1 : 4
# Points in patch 2 : 3
# Points in patch 3 : 7
# Number of Patches: 3
# Points in patch 1 : 6
# Points in patch 2 : 8
# Points in patch 3 : 10
# Number of Patches: 3
# Points in patch 1 : 4
# Points in patch 2 : 9
# Points in patch 3 : 10

# %%
pprint(HS.holo_volume_form)
# Out:
# [[[1/(4*z1**3), 1/(4*z2**3), 1/(4*z3**3)],
#   [1/(4*z1**3), 1/(4*z2**3), 1/(4*z3**3)],
#   [1/(4*z1**3), 1/(4*z2**3), 1/(4*z3**3)]],
#  [[1/(4*z0**3), 1/(4*z2**3), 1/(4*z3**3)],
#   [1/(4*z0**3), 1/(4*z2**3), 1/(4*z3**3)],
#   [1/(4*z0**3), 1/(4*z2**3), 1/(4*z3**3)]],
#  [[1/(4*z0**3), 1/(4*z1**3), 1/(4*z3**3)],
#   [1/(4*z0**3), 1/(4*z1**3), 1/(4*z3**3)],
#   [1/(4*z0**3), 1/(4*z1**3), 1/(4*z3**3)]],
#  [[1/(4*z0**3), 1/(4*z1**3), 1/(4*z2**3)],
#   [1/(4*z0**3), 1/(4*z1**3), 1/(4*z2**3)],
#   [1/(4*z0**3), 1/(4*z1**3), 1/(4*z2**3)]]]

# %%
pprint(HS.patches[0].patches[1].holo_volume_form)
# Out:
# [1/(4*z1**3), 1/(4*z2**3), 1/(4*z3**3)]

# %%
HS.integrate()
# Out:
# 0.52371319133955 - 0.0678492615191222*I

# %%
pprint(HS.patches[0].patches[1].points)
# Out:
# [[1,
#   -0.194865303957873 + 0.0944059039988618*I,
#   0.709844580018724 - 0.702301247313316*I,
#   -0.354406042969675 - 0.171383482332295*I],
#  [1,
#   -0.62612307841388 + 0.544497727102361*I,
#   0.569935010966305 - 0.633161667757157*I,
#   -0.256647996007303 + 0.350502911892288*I],
#  [1,
#   0.308761034118796 + 0.0613154440928442*I,
#   0.563694099554169 - 0.715715188577571*I,
#   -0.4866923462728 - 0.689766412022944*I],
#  [1,
#   0.250784745359482 + 0.60751273393177*I,
#   0.724372287502193 + 0.65374080009579*I,
#   -0.40831770122077 + 0.412321550999064*I],
#  [1,
#   0.52046953172831 - 0.284190661414445*I,
#   -0.676309928086906 + 0.716831089462119*I,
#   -0.248735608469097 - 0.219178758807107*I]]

# %%
pprint(HS.patches[0].patches[1].eval_all("grad"))
# Out:
# [[-0.00875729552067465 + 0.0396523622653935*I,
#   -2.77067047036164 - 2.8609250976012*I,
#   -0.0531421218540036 - 0.238180970502432*I],
#  [1.24574252909675 + 1.9157881436787*I,
#   -2.00128159704468 - 1.45268574152056*I,
#   0.310737772421555 + 0.104803581709318*I],
#  [0.103811171919318 + 0.069222817402771*I,
#   -2.74855812424461 - 1.2625355704423*I,
#   2.31755822593255 - 0.647913087399382*I],
#  [-1.04760028509207 - 0.438363586425494*I,
#   -2.19460432398129 + 2.9987576857232*I,
#   0.560708137646499 + 0.544529939470593*I],
#  [0.0595324237403506 - 0.831998022155369*I,
#   2.93287295638591 + 2.46113501927209*I,
#   0.0818326043740603 - 0.120608705869401*I]]

# %% [markdown]
# (z0*z1).subs(z1, sp.conjugate(z0))

# %%
patch = HS.patches[0].patches[0]

# %%
patch.omega_omegabar[0]
# Out:
# 1/(16*z1**3*conjugate(z1)**3)

# %%
H = np.identity(patch.n_sections)

# %%
patch.kahler_potential()
# Out:
# log(z1**4*H[0, 20] + z1**3*z2*H[0, 21] + z1**3*z3*H[0, 22] + z1**3*H[0, 10] + z1**2*z2**2*H[0, 23] + z1**2*z2*z3*H[0, 24] + z1**2*z2*H[0, 11] + z1**2*z3**2*H[0, 25] + z1**2*z3*H[0, 12] + z1**2*H[0, 4] + z1*z2**3*H[0, 26] + z1*z2**2*z3*H[0, 27] + z1*z2**2*H[0, 13] + z1*z2*z3**2*H[0, 28] + z1*z2*z3*H[0, 14] + z1*z2*H[0, 5] + z1*z3**3*H[0, 29] + z1*z3**2*H[0, 15] + z1*z3*H[0, 6] + z1*H[0, 1] + z2**4*H[0, 30] + z2**3*z3*H[0, 31] + z2**3*H[0, 16] + z2**2*z3**2*H[0, 32] + z2**2*z3*H[0, 17] + z2**2*H[0, 7] + z2*z3**3*H[0, 33] + z2*z3**2*H[0, 18] + z2*z3*H[0, 8] + z2*H[0, 2] + z3**4*H[0, 34] + z3**3*H[0, 19] + z3**2*H[0, 9] + z3*H[0, 3] + (z1**4*H[1, 20] + z1**3*z2*H[1, 21] + z1**3*z3*H[1, 22] + z1**3*H[1, 10] + z1**2*z2**2*H[1, 23] + z1**2*z2*z3*H[1, 24] + z1**2*z2*H[1, 11] + z1**2*z3**2*H[1, 25] + z1**2*z3*H[1, 12] + z1**2*H[1, 4] + z1*z2**3*H[1, 26] + z1*z2**2*z3*H[1, 27] + z1*z2**2*H[1, 13] + z1*z2*z3**2*H[1, 28] + z1*z2*z3*H[1, 14] + z1*z2*H[1, 5] + z1*z3**3*H[1, 29] + z1*z3**2*H[1, 15] + z1*z3*H[1, 6] + z1*H[1, 1] + z2**4*H[1, 30] + z2**3*z3*H[1, 31] + z2**3*H[1, 16] + z2**2*z3**2*H[1, 32] + z2**2*z3*H[1, 17] + z2**2*H[1, 7] + z2*z3**3*H[1, 33] + z2*z3**2*H[1, 18] + z2*z3*H[1, 8] + z2*H[1, 2] + z3**4*H[1, 34] + z3**3*H[1, 19] + z3**2*H[1, 9] + z3*H[1, 3] + H[1, 0])*conjugate(z1) + (z1**4*H[2, 20] + z1**3*z2*H[2, 21] + z1**3*z3*H[2, 22] + z1**3*H[2, 10] + z1**2*z2**2*H[2, 23] + z1**2*z2*z3*H[2, 24] + z1**2*z2*H[2, 11] + z1**2*z3**2*H[2, 25] + z1**2*z3*H[2, 12] + z1**2*H[2, 4] + z1*z2**3*H[2, 26] + z1*z2**2*z3*H[2, 27] + z1*z2**2*H[2, 13] + z1*z2*z3**2*H[2, 28] + z1*z2*z3*H[2, 14] + z1*z2*H[2, 5] + z1*z3**3*H[2, 29] + z1*z3**2*H[2, 15] + z1*z3*H[2, 6] + z1*H[2, 1] + z2**4*H[2, 30] + z2**3*z3*H[2, 31] + z2**3*H[2, 16] + z2**2*z3**2*H[2, 32] + z2**2*z3*H[2, 17] + z2**2*H[2, 7] + z2*z3**3*H[2, 33] + z2*z3**2*H[2, 18] + z2*z3*H[2, 8] + z2*H[2, 2] + z3**4*H[2, 34] + z3**3*H[2, 19] + z3**2*H[2, 9] + z3*H[2, 3] + H[2, 0])*conjugate(z2) + (z1**4*H[3, 20] + z1**3*z2*H[3, 21] + z1**3*z3*H[3, 22] + z1**3*H[3, 10] + z1**2*z2**2*H[3, 23] + z1**2*z2*z3*H[3, 24] + z1**2*z2*H[3, 11] + z1**2*z3**2*H[3, 25] + z1**2*z3*H[3, 12] + z1**2*H[3, 4] + z1*z2**3*H[3, 26] + z1*z2**2*z3*H[3, 27] + z1*z2**2*H[3, 13] + z1*z2*z3**2*H[3, 28] + z1*z2*z3*H[3, 14] + z1*z2*H[3, 5] + z1*z3**3*H[3, 29] + z1*z3**2*H[3, 15] + z1*z3*H[3, 6] + z1*H[3, 1] + z2**4*H[3, 30] + z2**3*z3*H[3, 31] + z2**3*H[3, 16] + z2**2*z3**2*H[3, 32] + z2**2*z3*H[3, 17] + z2**2*H[3, 7] + z2*z3**3*H[3, 33] + z2*z3**2*H[3, 18] + z2*z3*H[3, 8] + z2*H[3, 2] + z3**4*H[3, 34] + z3**3*H[3, 19] + z3**2*H[3, 9] + z3*H[3, 3] + H[3, 0])*conjugate(z3) + (z1**4*H[4, 20] + z1**3*z2*H[4, 21] + z1**3*z3*H[4, 22] + z1**3*H[4, 10] + z1**2*z2**2*H[4, 23] + z1**2*z2*z3*H[4, 24] + z1**2*z2*H[4, 11] + z1**2*z3**2*H[4, 25] + z1**2*z3*H[4, 12] + z1**2*H[4, 4] + z1*z2**3*H[4, 26] + z1*z2**2*z3*H[4, 27] + z1*z2**2*H[4, 13] + z1*z2*z3**2*H[4, 28] + z1*z2*z3*H[4, 14] + z1*z2*H[4, 5] + z1*z3**3*H[4, 29] + z1*z3**2*H[4, 15] + z1*z3*H[4, 6] + z1*H[4, 1] + z2**4*H[4, 30] + z2**3*z3*H[4, 31] + z2**3*H[4, 16] + z2**2*z3**2*H[4, 32] + z2**2*z3*H[4, 17] + z2**2*H[4, 7] + z2*z3**3*H[4, 33] + z2*z3**2*H[4, 18] + z2*z3*H[4, 8] + z2*H[4, 2] + z3**4*H[4, 34] + z3**3*H[4, 19] + z3**2*H[4, 9] + z3*H[4, 3] + H[4, 0])*conjugate(z1)**2 + (z1**4*H[5, 20] + z1**3*z2*H[5, 21] + z1**3*z3*H[5, 22] + z1**3*H[5, 10] + z1**2*z2**2*H[5, 23] + z1**2*z2*z3*H[5, 24] + z1**2*z2*H[5, 11] + z1**2*z3**2*H[5, 25] + z1**2*z3*H[5, 12] + z1**2*H[5, 4] + z1*z2**3*H[5, 26] + z1*z2**2*z3*H[5, 27] + z1*z2**2*H[5, 13] + z1*z2*z3**2*H[5, 28] + z1*z2*z3*H[5, 14] + z1*z2*H[5, 5] + z1*z3**3*H[5, 29] + z1*z3**2*H[5, 15] + z1*z3*H[5, 6] + z1*H[5, 1] + z2**4*H[5, 30] + z2**3*z3*H[5, 31] + z2**3*H[5, 16] + z2**2*z3**2*H[5, 32] + z2**2*z3*H[5, 17] + z2**2*H[5, 7] + z2*z3**3*H[5, 33] + z2*z3**2*H[5, 18] + z2*z3*H[5, 8] + z2*H[5, 2] + z3**4*H[5, 34] + z3**3*H[5, 19] + z3**2*H[5, 9] + z3*H[5, 3] + H[5, 0])*conjugate(z1)*conjugate(z2) + (z1**4*H[6, 20] + z1**3*z2*H[6, 21] + z ...

# %%
patch.eval_all(patch.kahler_potential(H))
# Out:
# [[2.23912424319543 + 1.8483786892551e-18*I],
#  [1.74626037166756 + 1.70200777326925e-19*I],
#  [3.40898050739924],
#  [2.47381476598912 + 7.42283045093406e-20*I]]

# %%
diff_conjugate(sp.conjugate(z0**2)*z0, z0)
# Out:
# 2*z0*conjugate(z0)

# %%
from sympy import I
diff_conjugate(sp.conjugate(z0**2)*z0, z0).subs(z0, 1+I)
# Out:
# 2*(1 - I)*(1 + I)

# %%
sp.simplify(diff_conjugate(sp.conjugate(z0**2)*z0, z0).subs(z0, 1+I))
# Out:
# 4

# %%
kahler_metric = patch.kahler_metric(H)

# %%
kahler_metric[0,0]
# Out:
# (1.0*z1**3*z3*conjugate(z1)**3 + 1.0*z1**2*z2*z3*conjugate(z1)**2*conjugate(z2) + 2.0*z1**2*z3**2*conjugate(z1)**2*conjugate(z3) + 1.0*z1**2*z3*conjugate(z1)**2 + 1.0*z1*z2**2*z3*conjugate(z1)*conjugate(z2)**2 + 2.0*z1*z2*z3**2*conjugate(z1)*conjugate(z2)*conjugate(z3) + 1.0*z1*z2*z3*conjugate(z1)*conjugate(z2) + 3.0*z1*z3**3*conjugate(z1)*conjugate(z3)**2 + 2.0*z1*z3**2*conjugate(z1)*conjugate(z3) + 1.0*z1*z3*conjugate(z1) + 1.0*z2**3*z3*conjugate(z2)**3 + 2.0*z2**2*z3**2*conjugate(z2)**2*conjugate(z3) + 1.0*z2**2*z3*conjugate(z2)**2 + 3.0*z2*z3**3*conjugate(z2)*conjugate(z3)**2 + 2.0*z2*z3**2*conjugate(z2)*conjugate(z3) + 1.0*z2*z3*conjugate(z2) + 4.0*z3**4*conjugate(z3)**3 + 3.0*z3**3*conjugate(z3)**2 + 2.0*z3**2*conjugate(z3) + 1.0*z3)*(-4.0*z1**4*conjugate(z1)**3*Derivative(conjugate(z1), z1) - 3.0*z1**3*z2*conjugate(z1)**2*conjugate(z2)*Derivative(conjugate(z1), z1) - 3.0*z1**3*z3*conjugate(z1)**2*conjugate(z3)*Derivative(conjugate(z1), z1) - 4.0*z1**3*conjugate(z1)**4 - 3.0*z1**3*conjugate(z1)**2*Derivative(conjugate(z1), z1) - 2.0*z1**2*z2**2*conjugate(z1)*conjugate(z2)**2*Derivative(conjugate(z1), z1) - 2.0*z1**2*z2*z3*conjugate(z1)*conjugate(z2)*conjugate(z3)*Derivative(conjugate(z1), z1) - 3.0*z1**2*z2*conjugate(z1)**3*conjugate(z2) - 2.0*z1**2*z2*conjugate(z1)*conjugate(z2)*Derivative(conjugate(z1), z1) - 2.0*z1**2*z3**2*conjugate(z1)*conjugate(z3)**2*Derivative(conjugate(z1), z1) - 3.0*z1**2*z3*conjugate(z1)**3*conjugate(z3) - 2.0*z1**2*z3*conjugate(z1)*conjugate(z3)*Derivative(conjugate(z1), z1) - 3.0*z1**2*conjugate(z1)**3 - 2.0*z1**2*conjugate(z1)*Derivative(conjugate(z1), z1) - 1.0*z1*z2**3*conjugate(z2)**3*Derivative(conjugate(z1), z1) - 1.0*z1*z2**2*z3*conjugate(z2)**2*conjugate(z3)*Derivative(conjugate(z1), z1) - 2.0*z1*z2**2*conjugate(z1)**2*conjugate(z2)**2 - 1.0*z1*z2**2*conjugate(z2)**2*Derivative(conjugate(z1), z1) - 1.0*z1*z2*z3**2*conjugate(z2)*conjugate(z3)**2*Derivative(conjugate(z1), z1) - 2.0*z1*z2*z3*conjugate(z1)**2*conjugate(z2)*conjugate(z3) - 1.0*z1*z2*z3*conjugate(z2)*conjugate(z3)*Derivative(conjugate(z1), z1) - 2.0*z1*z2*conjugate(z1)**2*conjugate(z2) - 1.0*z1*z2*conjugate(z2)*Derivative(conjugate(z1), z1) - 1.0*z1*z3**3*conjugate(z3)**3*Derivative(conjugate(z1), z1) - 2.0*z1*z3**2*conjugate(z1)**2*conjugate(z3)**2 - 1.0*z1*z3**2*conjugate(z3)**2*Derivative(conjugate(z1), z1) - 2.0*z1*z3*conjugate(z1)**2*conjugate(z3) - 1.0*z1*z3*conjugate(z3)*Derivative(conjugate(z1), z1) - 2.0*z1*conjugate(z1)**2 - 1.0*z1*Derivative(conjugate(z1), z1) - 1.0*z2**3*conjugate(z1)*conjugate(z2)**3 - 1.0*z2**2*z3*conjugate(z1)*conjugate(z2)**2*conjugate(z3) - 1.0*z2**2*conjugate(z1)*conjugate(z2)**2 - 1.0*z2*z3**2*conjugate(z1)*conjugate(z2)*conjugate(z3)**2 - 1.0*z2*z3*conjugate(z1)*conjugate(z2)*conjugate(z3) - 1.0*z2*conjugate(z1)*conjugate(z2) - 1.0*z3**3*conjugate(z1)*conjugate(z3)**3 - 1.0*z3**2*conjugate(z1)*conjugate(z3)**2 - 1.0*z3*conjugate(z1)*conjugate(z3) - 1.0*conjugate(z1))/(1.0*z1**4*conjugate(z1)**4 + 1.0*z1**3*z2*conjugate(z1)**3*conjugate(z2) + 1.0*z1**3*z3*conjugate(z1)**3*conjugate(z3) + 1.0*z1**3*conjugate(z1)**3 + 1.0*z1**2*z2**2*conjugate(z1)**2*conjugate(z2)**2 + 1.0*z1**2*z2*z3*conjugate(z1)**2*conjugate(z2)*conjugate(z3) + 1.0*z1**2*z2*conjugate(z1)**2*conjugate(z2) + 1.0*z1**2*z3**2*conjugate(z1)**2*conjugate(z3)**2 + 1.0*z1**2*z3*conjugate(z1)**2*conjugate(z3) + 1.0*z1**2*conjugate(z1)**2 + 1.0*z1*z2**3*conjugate(z1)*conjugate(z2)**3 + 1.0*z1*z2**2*z3*conjugate(z1)*conjugate(z2)**2*conjugate(z3) + 1.0*z1*z2**2*conjugate(z1)*conjugate(z2)**2 + 1.0*z1*z2*z3**2*conjugate(z1)*conjugate(z2)*conjugate(z3)**2 + 1.0*z1*z2*z3*conjugate(z1)*conjugate(z2)*conjugate(z3) + 1.0*z1*z2*conjugate(z1)*conjugate(z2) + 1.0*z1*z3**3*conjugate(z1)*conjugate(z3)**3 + 1.0*z1*z3**2*conjugate(z1)*conjugate(z3)**2 + 1.0*z1*z3*conjugate(z1)*conjugate(z3) + 1.0*z1*conjugate(z1) + 1.0*z2**4*conjugate(z2)**4 + 1.0*z2**3*z3*conjugate(z2)**3*conjugate(z3) + 1.0*z2**3*conjugate(z2)**3 + 1.0*z2**2*z3**2*conjugate( ...

# %%
sp.diff(z0,z0.conjugate())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a2c407d48ffa> in <module>
# ----> 1 sp.diff(z0,z0.conjugate())
#
# /usr/local/lib/python3.7/site-packages/sympy/core/function.py in diff(f, *symbols, **kwargs)
#    2310     """
#    2311     if hasattr(f, 'diff'):
# -> 2312         return f.diff(*symbols, **kwargs)
#    2313     kwargs.setdefault('evaluate', True)
#    2314     return Derivative(f, *symbols, **kwargs)
#
# /usr/local/lib/python3.7/site-packages/sympy/core/expr.py in diff(self, *symbols, **assumptions)
#    3093     def diff(self, *symbols, **assumptions):
#    3094         assumptions.setdefault("evaluate", True)
# -> 3095         return Derivative(self, *symbols, **assumptions)
#    3096
#    3097     ###########################################################################
#
# /usr/local/lib/python3.7/site-packages/sympy/core/function.py in __new__(cls, expr, *variables, **kwargs)
#    1285                 raise ValueError(filldedent('''
#    1286                     Can't calculate derivative wrt %s.%s''' % (v,
# -> 1287                     __)))
#    1288
#    1289         # We make a special case for 0th derivative, because there is no
#
# ValueError:
# Can't calculate derivative wrt conjugate(z0).
